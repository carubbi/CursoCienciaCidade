# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df_ipea = pd.read_csv('dataset/ipeadata[04-10-2024-03-44].csv', skiprows=1)
df_ipea.head()
# Out:
#   Sigla   Código     Município  1872  1890  1910  1920    1940    1950  \
# 0    AC  1200013    Acrelândia   NaN   NaN   NaN   NaN     NaN     NaN
# 1    AC  1200054  Assis Brasil   NaN   NaN   NaN   NaN     NaN     NaN
# 2    AC  1200104     Brasiléia   NaN   NaN   NaN   NaN  6723.0  7864.0
# 3    AC  1200138        Bujari   NaN   NaN   NaN   NaN     NaN     NaN
# 4    AC  1200179      Capixaba   NaN   NaN   NaN   NaN     NaN     NaN
#
#       1960     1970     1980     1991     1996     2000     2007     2010  \
# 0      NaN      NaN      NaN      NaN   6308.0   7935.0  11520.0  12538.0
# 1      NaN      NaN   1367.0   2917.0   2918.0   3490.0   5351.0   6072.0
# 2  10423.0  12311.0  13907.0  20263.0  13955.0  17013.0  19065.0  21398.0
# 3      NaN      NaN      NaN      NaN   4101.0   5826.0   6543.0   8471.0
# 4      NaN      NaN      NaN      NaN   2903.0   5206.0   8446.0   8798.0
#
#       2022  Unnamed: 18
# 0  14021.0          NaN
# 1   8100.0          NaN
# 2  26000.0          NaN
# 3  12917.0          NaN
# 4  10392.0          NaN

# %%
df = df_ipea[['Município', '2022']]
df.columns = ['MUNICIPIO','2022']
df = df.dropna()
df.head()
# Out:
#       MUNICIPIO     2022
# 0    Acrelândia  14021.0
# 1  Assis Brasil   8100.0
# 2     Brasiléia  26000.0
# 3        Bujari  12917.0
# 4      Capixaba  10392.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5570 entries, 0 to 5595
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MUNICIPIO  5570 non-null   object
#  1   2022       5570 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 130.5+ KB

# %%
df2022_ordenado = df.sort_values(by='2022', ascending=False).reset_index(drop=True)
df2022_ordenado.head()
# Out:
#         MUNICIPIO        2022
# 0       São Paulo  11451999.0
# 1  Rio de Janeiro   6211223.0
# 2        Brasília   2817381.0
# 3       Fortaleza   2428708.0
# 4        Salvador   2417678.0

# %%
ranks = df2022_ordenado.index + 1
values = df2022_ordenado['2022']
zipf_values = values.max() / ranks

# %%
fig, ax = plt.subplots(figsize=(6, 4), tight_layout=True)
# ax.plot(ranks, values, marker = 'x')
ax.scatter(ranks, values, marker = 'x', color = 'red')
ax.plot(ranks, zipf_values)
ax.set_xscale('log')
ax.set_yscale('log')
ax.label()
plt.show()
